# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import openpyxl
import matplotlib

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
DIR = '/content/drive/MyDrive/Colab Notebooks/Datasets/'

# %%
df_times = pd.read_excel(DIR + 'lista_time.xlsx')

# %%
df_times.head(2)
# Out:
#          Clube           Stadium  vlr_gasto (em milhões de Euros)  Capacity  \
# 0      Arsenal  Emirates Stadium                            66.85     60704
# 1  Aston Villa        Villa Park                            98.58     42682
#
#         Managers     Nat.  Became Manager                    Logo
# 0  Mikel Arteta     Spain      2019-12-22  https://ibb.co/mNnfdnh
# 1    Dean Smith   England      2018-10-10  https://ibb.co/RCf3ysY

# %%
df_dados_jogadores = pd.read_csv(DIR + 'league_player_data_20_21.csv', sep=',')
df_dados_jogadores.head(5)
# Out:
#      id      player_name  games  time  goals         xG  assists         xA  \
# 0   647       Harry Kane     35  3097     23  22.174859       14   7.577094
# 1  1250    Mohamed Salah     37  3085     22  20.250847        5   6.528526
# 2  1228  Bruno Fernandes     37  3117     18  16.019454       12  11.474996
# 3   453    Son Heung-Min     37  3139     17  11.023287       10   9.512992
# 4   822  Patrick Bamford     38  3085     17  18.401863        7   3.782247
#
#    shots  key_passes  yellow_cards  red_cards position         team_title  \
# 0    138          49             1          0        F          Tottenham
# 1    126          55             0          0    F M S          Liverpool
# 2    121          95             6          0      M S  Manchester United
# 3     68          75             0          0    F M S          Tottenham
# 4    107          30             3          0      F S              Leeds
#
#    npg       npxG    xGChain  xGBuildup
# ...

# %%
df_class = pd.read_excel(DIR + 'classificacao.xlsx')
df_class.head(5)
# Out:
#    Posição              Clube  Pontos  Jogos  Vitorias  Empates  Derrotas  \
# 0        1    Manchester City      86     38        27        5         6
# 1        2  Manchester United      74     38        21       11         6
# 2        3          Liverpool      69     38        20        9         9
# 3        4            Chelsea      67     38        19       10         9
# 4        5     Leicester City      66     38        20        6        12
#
#    Gols Pro  Gols Contra  Saldo de Gols
# 0        83           32             51
# 1        73           44             29
# 2        68           42             26
# 3        58           36             22
# 4        68           50             18

# %%
df_clube = pd.merge(df_class, df_times, on='Clube', how='outer')
df_clube.head(2)
# Out:
#    Posição              Clube  Pontos  Jogos  Vitorias  Empates  Derrotas  \
# 0      1.0    Manchester City    86.0   38.0      27.0      5.0       6.0
# 1      2.0  Manchester United    74.0   38.0      21.0     11.0       6.0
#
#    Gols Pro  Gols Contra  Saldo de Gols         Stadium  \
# 0      83.0         32.0           51.0  Etihad Stadium
# 1      73.0         44.0           29.0    Old Trafford
#
#    vlr_gasto (em milhões de Euros)  Capacity              Managers    Nat.   \
# 0                            109.4   55017.0        Pep Guardiola    Spain
# 1                             64.3   74879.0  Ole Gunnar Solskjær   Norway
#
#   Became Manager                    Logo
# 0     2016-07-01  https://ibb.co/19YrKRX
# 1     2018-12-19  https://ibb.co/wgvLV0s

# %%
df_clube = df_clube.rename(columns={'Stadium':'Estadio', 'Capacity':'Capacidade','Managers':'Tecnico','Nat.':'Nacionalidade','Became Manager':'Data de Adimissão'})
df_clube.head(2)
# Out:
#    Posição              Clube  Pontos  Jogos  Vitorias  Empates  Derrotas  \
# 0      1.0    Manchester City    86.0   38.0      27.0      5.0       6.0
# 1      2.0  Manchester United    74.0   38.0      21.0     11.0       6.0
#
#    Gols Pro  Gols Contra  Saldo de Gols         Estadio  \
# 0      83.0         32.0           51.0  Etihad Stadium
# 1      73.0         44.0           29.0    Old Trafford
#
#    vlr_gasto (em milhões de Euros)  Capacidade               Tecnico    Nat.   \
# 0                            109.4     55017.0        Pep Guardiola    Spain
# 1                             64.3     74879.0  Ole Gunnar Solskjær   Norway
#
#   Data de Adimissão                    Logo
# 0        2016-07-01  https://ibb.co/19YrKRX
# 1        2018-12-19  https://ibb.co/wgvLV0s

# %%
df_clube.to_excel(DIR + 'dataset_times.xlsx', index=False)

# %%
df_dados_jogadores = df_dados_jogadores.rename(columns={'id':'cod_jogador', 'player_name':'Nome Jogador', 'games':'Jogos','time':'Minutos Jogados', 'goals':'Gols Marcados',	'assists': 'Assitencias', 'shots':'Chutes', 'key_passes':'Passes bons', 'yellow_cards':'Cartões Amarelos',	'red_cards':'cartões vermelhos', 'position':'Posição jogador'})
df_dados_jogadores.head(20)
# Out:
#    cod_jogador   Nome Jogador  Jogos  Minutos Jogados  Gols Marcados  \
# 0          647     Harry Kane     35             3097             23
# 1         1250  Mohamed Salah     37             3085             22
#
#           xG  Assitencias        xA  Chutes  Passes bons  Cartões Amarelos  \
# 0  22.174859           14  7.577094     138           49                 1
# 1  20.250847            5  6.528526     126           55                 0
#
#    cartões vermelhos Posição jogador team_title  npg       npxG    xGChain  \
# 0                  0               F  Tottenham   19  19.130183  24.995648
# 1                  0           F M S  Liverpool   16  15.683834  28.968234
#
#    xGBuildup
# 0   4.451257
# 1   9.800236

# %%
df_artilharia = df_dados_jogadores.head(20)
df_artilharia
# Out:
#     cod_jogador               Nome Jogador  Jogos  Minutos Jogados  \
# 0           647                 Harry Kane     35             3097
# 1          1250              Mohamed Salah     37             3085
# 2          1228            Bruno Fernandes     37             3117
# 3           453              Son Heung-Min     37             3139
# 4           822            Patrick Bamford     38             3085
# 5          5555      Dominic Calvert-Lewin     33             2878
# 6           755                Jamie Vardy     34             2848
# 7          8865              Ollie Watkins     37             3330
# 8           314             Ilkay Gündogan     28             2033
# 9          3277        Alexandre Lacazette     31             1939
# 10          468              Callum Wilson     26             2079
# 11          620          Kelechi Iheanacho     25             1452
# 12          986                 Danny Ings     29             2200
# ...

# %%
df_artilharia.to_excel(DIR + 'dataset_artilheiros.xlsx', index=False)

# %%
df_dados_jogadores.to_excel(DIR + 'dataset_jogadores.xlsx', index=False)
